# %%
import duckdb
import os

# Get Wasabi credentials from environment
wasabi_endpoint = os.getenv('WASABI_ENDPOINT', 's3.us-east-2.wasabisys.com')
wasabi_access_key = os.getenv('WASABI_ACCESS_KEY')
wasabi_secret_key = os.getenv('WASABI_SECRET_KEY')
bucket_name = os.getenv('WASABI_BUCKET_NAME')

# Create DuckDB connection
con = duckdb.connect()

# Configure S3 settings
con.execute(f"""
    SET s3_endpoint='{wasabi_endpoint}';
    SET s3_access_key_id='{wasabi_access_key}';
    SET s3_secret_access_key='{wasabi_secret_key}';
    SET s3_url_style='path';
    SET preserve_insertion_order = false;
    SET enable_progress_bar = true;
""")

print("✓ DuckDB configured with S3 credentials")
print(f"Endpoint: {wasabi_endpoint}")
print('Bucket Name: ', bucket_name, '\n\n')
# Out:
# ✓ DuckDB configured with S3 credentials
# Endpoint: s3.us-east-2.wasabisys.com
# Bucket Name:  dfscrunch-data-lake

# %%
sport = "NFL"
lineups_dds_path = f"s3://{bucket_name}/dds/{sport}/lineups/dk_single_game/*/data.parquet"

# %%
lineups_df = con.execute(
    f"""
    SELECT * FROM parquet_scan('{lineups_dds_path}') limit 10;
    """
).df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
lineups_df
# Out:
#      contest_id                          lineup_hash  lineup_ct  \
# 0     167757150   47519:46269:63612:122689:2952:8493          4
# 1     167757150   47519:46269:63612:122689:2952:8493          4
# 2     167757109  2952:146167:47519:46269:122689:8493          1
# 3     167757109   47519:46269:63612:122689:2952:8493          2
# 4     167757166  33516:61444:29304:6816:134955:33718         14
# ..          ...                                  ...        ...
# 300   166872314  146167:25839:58170:55222:8466:33456          1
# 301   166872314  58170:58465:146167:63612:8466:33456          2
# 302   166872315  146167:58465:58170:55222:61795:8466         61
# 303   166872315  146167:58465:58170:63612:8466:33456          4
# 304   166872315  58170:58465:146167:63612:8466:33456          7
#
#      lineup_user_ct  points  total_salary  total_own  min_own  max_own  \
# 0                 4   94.54         47400     159.61      0.0    60.69
# 1                 4   94.54         47400     159.61      0.0    60.69
# 2                 1   95.44         47500     239.69      0.0    81.78
# 3                 2   94.54         47400     154.67      0.0    55.83
# 4                14  145.78         50000     194.40      0.0    58.59
# ..              ...     ...           ...        ...      ...      ...
# 300               1  119.25         48000     160.31      0.0    74.11
# 301               2  119.81         49500     178.27      0.0    83.10
# 302              61  119.11         49400     169.52      0.0    80.58
# 303               4  120.31         49800     180.51      0.0    80.58
# 304               7  119.81         49500     183.37      0.0    80.58
#
#      avg_own  ...  pos_cpt1  pos_flex1  pos_flex2  pos_flex3  pos_flex4  \
# 0      26.60  ...     47519      46269      63612     122689       2952
# 1      26.60  ...     47519      46269      63612     122689       2952
# 2      39.95  ...      2952     146167      47519      46269     122689
# 3      25.78  ...     47519      46269      63612     122689       2952
# 4      32.40  ...     33516      61444      29304       6816     134955
# ..       ...  ...       ...        ...        ...        ...        ...
# 300    26.72  ...    146167      25839      58170      55222       8466
# 301    29.71  ...     58170      58465     146167      63612       8466
# 302    28.25  ...    146167      58465      58170      55222      61795
# 303    30.08  ...    146167      58465      58170      63612       8466
# 304    30.56  ...     58170      58465     146167      63612       8466
#
#      pos_flex5                                        team_stacks  \
# 0         8493  {"1965":["47519:1","122689:0","2952:0","8493:0...
# 1         8493  {"1965":["47519:1","122689:0","2952:0","8493:0...
# 2         8493  {"1965":["2952:1","47519:0","122689:0","8493:0...
# 3         8493  {"1965":["47519:1","122689:0","2952:0","8493:0...
# 4        33718                          {"1965":null,"1990":null}
# ..         ...                                                ...
# 300      33456  {"2207":["58170:0","55222:0","8466:0"],"1990":...
# 301      33456  {"2207":["58170:1","58465:0","8466:0"],"1990":...
# 302       8466  {"2207":["58465:0","58170:0","55222:0","61795:...
# 303      33456  {"2207":["58465:0","58170:0","8466:0"],"1990":...
# 304      33456  {"2207":["58170:1","58465:0","8466:0"],"1990":...
#
#                                            game_stacks  \
# 0     {"6223120":[47519,46269,63612,122689,2952,8493]}
# 1     {"6223120":[47519,46269,63612,122689,2952,8493]}
# 2    {"6223120":[2952,146167,47519,46269,122689,8493]}
# 3     {"6223120":[47519,46269,63612,122689,2952,8493]}
# 4                                     {"6223120":null}
# ..                                                 ...
# 300  {"6212000":[146167,25839,58170,55222,8466,33456]}
# 301  {"6212000":[58170,58465,146167,63612,8466,33456]}
# 302  {"6212000":[146167,58465,58170,55222,61795,8466]}
# 303  {"6212000":[146167,58465,58170,63612,8466,33456]}
# 304  {"6212000":[58170,58465,146167,63612,8466,33456]}
#
#                                          lineup_trends  \
# 0    {"qbPairedWithPassCatcher":true,"qbStackPaired...
# 1    {"qbPairedWithPassCatcher":true,"qbStackPaired...
# 2    {"qbPairedWithPassCatcher":false,"qbStackPaire...
# 3    {"qbPairedWithPassCatcher":true,"qbStackPaired...
# 4    {"qbPairedWithPassCatcher":true,"qbStackPaired...
# ..                                                 ...
# 300  {"qbPairedWithPassCatcher":false,"qbStackPaire...
# 301  {"qbPairedWithPassCatcher":false,"qbStackPaire...
# 302  {"qbPairedWithPassCatcher":true,"qbStackPaired...
# 303  {"qbPairedWithPassCatcher":false,"qbStackPaire...
# 304  {"qbPairedWithPassCatcher":false,"qbStackPaire...
#
#                                        entry_name_list
# 0        ["oxenduck","EmileHeskey","hishboo","Mauk87"]
# 1        ["oxenduck","EmileHeskey","hishboo","Mauk87"]
# 2                                         ["Lilsoupy"]
# 3                               ["oxenduck","hishboo"]
# 4    ["oxenduck","justintime29","luckychuck","fours...
# ..                                                 ...
# 300                                        ["SoyPapa"]
# 301                          ["bcplumbing","Flip2108"]
# 302  ["pgk8","JRucker504","heart.chakra","HChambers...
# 303    ["Skreat","aznbeerman","DaSnipers","Schilly23"]
# 304  ["Prettybadge69","scottvad","kevinroach","zeed...
#
# [305 rows x 29 columns]

# %%
contests_path = f"s3://{bucket_name}/dds/{sport}/contests/dk_single_game/*/data.parquet"
# Out:
# contest_id            305
# lineup_hash           305
# lineup_ct             305
# lineup_user_ct        305
# points                305
# total_salary          305
# total_own             305
# min_own               305
# max_own               305
# avg_own               305
# lineup_rank           305
# is_cashing            305
# favorite_ct           305
# underdog_ct           305
# home_ct               305
# visitor_ct            305
# payout                305
# lineup_percentile     305
# correlated_players    305
# pos_cpt1              305
# pos_flex1             305
# pos_flex2             305
# pos_flex3             305
# pos_flex4             305
# pos_flex5             305
# team_stacks           305
# game_stacks           305
# lineup_trends         305
# entry_name_list       305
# dtype: int64

# %%
contests_df = con.execute(
    f"""
        SELECT
            contest_id,
            ceil(contest_size * 0.01) as top_1_percent_max_position,
         FROM parquet_scan('{contests_path}') limit 10;
    """
).df()

# %%
contests_df
# Out:
#    contest_id  top_1_percent_max_position
# 0   164284864                         1.0
# 1   164284865                         2.0
# 2   164284866                         1.0
# 3   164284880                         3.0
# 4   164284868                        26.0
# 5   164284869                        53.0
# 6   164284870                      1961.0
# 7   166617480                       118.0
# 8   164284862                        50.0
# 9   164284893                       298.0

# %%
players_path = f"s3://{bucket_name}/dds/{sport}/players/dk_single_game/*/data.parquet"
top_lineups_df = con.execute(
    f"""
        WITH
            lineups AS (
                SELECT
                    replace(list_element(string_split(filename, '/'), -2), '-', '')::integer as date_id,
                    contest_id,
                    lineup_rank,
                    total_own,
                    total_salary,
                    pos_cpt1,
                    pos_flex1,
                    pos_flex2,
                    pos_flex3,
                    pos_flex4,
                    pos_flex5
                FROM parquet_scan('{lineups_dds_path}')
                WHERE lineup_percentile <= 0.01
            ),
            -- Unpivot lineup positions to enable single join
            lineup_positions AS (
                SELECT
                    date_id,
                    contest_id,
                    lineup_rank,
                    total_own,
                    total_salary,
                    unnest(['cpt1', 'flex1', 'flex2', 'flex3', 'flex4', 'flex5']) as pos_slot,
                    unnest([pos_cpt1, pos_flex1, pos_flex2, pos_flex3, pos_flex4, pos_flex5]) as player_id
                FROM lineups
            ),
            -- Pre-filter to only load players that appear in top lineups
            needed_players AS (
                SELECT DISTINCT date_id, player_id
                FROM lineup_positions
            ),
            -- Load only the players we need, with team and salary info
            players AS (
                SELECT
                    replace(list_element(string_split(filename, '/'), -2), '-', '')::integer as date_id,
                    p.player_id,
                    p.position,
                    p.current_team,
                    p.salary,
                    p.roster_position
                FROM parquet_scan('{players_path}') p
                WHERE (replace(list_element(string_split(filename, '/'), -2), '-', '')::integer, p.player_id) IN 
                      (SELECT date_id, player_id FROM needed_players)
            )
            -- Single join with roster position matching and pivot back to wide format
            SELECT
                contest_id,
                lineup_rank,
                max(total_own) as total_own,
                max(total_salary) as total_salary,
                max(CASE WHEN pos_slot = 'cpt1' THEN position END) as pos_cpt1_real,
                max(CASE WHEN pos_slot = 'cpt1' THEN current_team END) as pos_cpt1_team,
                max(CASE WHEN pos_slot = 'cpt1' THEN salary END) as pos_cpt1_salary,
                max(CASE WHEN pos_slot = 'flex1' THEN position END) as pos_flex1_real,
                max(CASE WHEN pos_slot = 'flex1' THEN current_team END) as pos_flex1_team,
                max(CASE WHEN pos_slot = 'flex1' THEN salary END) as pos_flex1_salary,
                max(CASE WHEN pos_slot = 'flex2' THEN position END) as pos_flex2_real,
                max(CASE WHEN pos_slot = 'flex2' THEN current_team END) as pos_flex2_team,
                max(CASE WHEN pos_slot = 'flex2' THEN salary END) as pos_flex2_salary,
                max(CASE WHEN pos_slot = 'flex3' THEN position END) as pos_flex3_real,
                max(CASE WHEN pos_slot = 'flex3' THEN current_team END) as pos_flex3_team,
                max(CASE WHEN pos_slot = 'flex3' THEN salary END) as pos_flex3_salary,
                max(CASE WHEN pos_slot = 'flex4' THEN position END) as pos_flex4_real,
                max(CASE WHEN pos_slot = 'flex4' THEN current_team END) as pos_flex4_team,
                max(CASE WHEN pos_slot = 'flex4' THEN salary END) as pos_flex4_salary,
                max(CASE WHEN pos_slot = 'flex5' THEN position END) as pos_flex5_real,
                max(CASE WHEN pos_slot = 'flex5' THEN current_team END) as pos_flex5_team,
                max(CASE WHEN pos_slot = 'flex5' THEN salary END) as pos_flex5_salary
            FROM lineup_positions lp
                JOIN players p ON lp.player_id = p.player_id 
                    AND lp.date_id = p.date_id
                    AND ((lp.pos_slot = 'cpt1' AND p.roster_position = 'CPT') 
                        OR (lp.pos_slot != 'cpt1' AND p.roster_position != 'CPT'))
            GROUP BY contest_id, lineup_rank
    """
).df()

# %%
top_lineups_df
# Out:
#      contest_id  lineup_rank  total_own  total_salary pos_cpt1_real  \
# 0     167604243            1     201.28         48600            WR
# 1     167604256           27     184.41         48600            WR
# 2     164284870           14     255.74         49100            WR
# 3     181656897            1     212.07         49500            WR
# 4     181976084           11     132.37         48000            RB
# ..          ...          ...        ...           ...           ...
# 284   166661327           17     252.26         39200            WR
# 285   166661329           17     176.74         39600            WR
# 286   166661329            5     222.32         40100            RB
# 287   166661330            7     262.97         41200             K
# 288   182613638            1     159.69         47200            QB
#
#     pos_cpt1_team  pos_cpt1_salary pos_flex1_real pos_flex1_team  \
# 0             NYG            16200             WR            DAL
# 1             NYG            16200             WR            DAL
# 2              KC             8700             QB            BAL
# 3             BUF             9900             QB            BUF
# 4             ATL            18000             WR            MIN
# ..            ...              ...            ...            ...
# 284           NYJ             3000             WR            NYJ
# 285            SF            14400             RB            NYJ
# 286            SF             4500             RB            NYJ
# 287            SF             7200             RB            NYJ
# 288           ARI            16200             QB            SEA
#
#      pos_flex1_salary  ... pos_flex2_salary pos_flex3_real  pos_flex3_team  \
# 0               11800  ...             6400              K             DAL
# 1               11800  ...             6400              K             DAL
# 2               11400  ...            10400             RB              KC
# 3               11000  ...            10200             WR             BAL
# 4               11800  ...             7000              K             ATL
# ..                ...  ...              ...            ...             ...
# 284              9800  ...             9600             QB             NYJ
# 285             10200  ...             5200              K              SF
# 286             10200  ...             9600             QB             NYJ
# 287             10200  ...             9600             QB              SF
# 288             10000  ...             7800             RB             SEA
#
#     pos_flex3_salary pos_flex4_real  pos_flex4_team pos_flex4_salary  \
# 0               5000             WR             NYG             4800
# 1               5000             WR             NYG             4800
# 2               8400             WR              KC             7600
# 3               8200             TE             BUF             5600
# 4               4600              D             ATL             3600
# ..               ...            ...             ...              ...
# 284             9000              K              SF             4800
# 285             4800             RB              SF             3000
# 286             9000              K              SF             4800
# 287             9200             RB              SF             3000
# 288             5400              K             SEA             5000
#
#     pos_flex5_real  pos_flex5_team pos_flex5_salary
# 0                K             NYG             4400
# 1                K             NYG             4400
# 2               TE             BAL             2600
# 3                K             BAL             4600
# 4               RB             ATL             3000
# ..             ...             ...              ...
# 284             RB              SF             3000
# 285             WR             NYJ             2000
# 286             WR             NYJ             2000
# 287             WR             NYJ             2000
# 288             TE             SEA             2800
#
# [289 rows x 22 columns]

# %%
players_path = f"s3://{bucket_name}/dds/{sport}/players/dk_single_game/*/data.parquet"
players_df = con.execute(
    f"""
        select * from parquet_scan('{players_path}');
    """
).df()
# Out:
#      contest_id  lineup_rank  total_own  total_salary pos_cpt1_real  \
# 0     167598784            1     140.79         50000            QB
# 1     181656897            1     212.07         49500            WR
# 2     167604249            2     251.60         49700             K
# 3     167604243            1     201.28         48600            WR
# 4     167604256           27     184.41         48600            WR
# ..          ...          ...        ...           ...           ...
# 732   166661329            5     222.32         40100            RB
# 733   166661330           86     171.81         31300            RB
# 734   166661330           48     261.61         39200            WR
# 735   166661330            7     262.97         41200             K
# 736   166661330           57     211.46         43200            WR
#
#     pos_flex1_real pos_flex2_real pos_flex3_real pos_flex4_real pos_flex5_real
# 0               RB             TE             WR              D             RB
# 1               QB             RB             WR             TE              K
# 2               WR             WR             QB             WR              K
# 3               WR             RB              K             WR              K
# 4               WR             RB              K             WR              K
# ..             ...            ...            ...            ...            ...
# 732             RB             WR             QB              K             WR
# 733             RB             QB              K             WR             FB
# 734             RB             QB             QB              K             RB
# 735             RB             WR             QB             RB             WR
# 736             WR             QB              K             RB             WR
#
# [734 rows x 10 columns]

# %%
players_df
# Out:
#       player_key  player_id first_name last_name        full_name  salary  \
# 0       265928:1     265928     Izaiah  Gathings  Izaiah Gathings     300
# 1       170960:0     170960     Xavier    Worthy    Xavier Worthy    5800
# 2       167855:0     167855     Carson    Steele    Carson Steele     200
# 3       148325:1     148325    Rasheen       Ali      Rasheen Ali     300
# 4       148325:0     148325    Rasheen       Ali      Rasheen Ali     200
# ...          ...        ...        ...       ...              ...     ...
# 10710    40643:0      40643      Mason   Rudolph    Mason Rudolph    6000
# 10711    49557:1      49557       Jake  Ferguson    Jake Ferguson   12600
# 10712    45261:0      45261       Josh     Whyle       Josh Whyle     200
# 10713     8471:0       8471     Dallas   Defense   Dallas Defense    3400
# 10714     5150:0       5150    Brandon   McManus  Brandon McManus    5200
#
#       position roster_position current_team  current_team_id  event_id  \
# 0           WR             CPT                          2102   6209760
# 1           WR              WR           KC             2102   6209760
# 2           FB              RB           KC             2102   6209760
# 3           RB             CPT          BAL             2170   6209760
# 4           RB              RB          BAL             2170   6209760
# ...        ...             ...          ...              ...       ...
# 10710       QB              QB          PIT             2198   7943380
# 10711       TE             CPT          DAL             2237   7949260
# 10712       TE              TE           GB             2062   7949260
# 10713        D               D          DAL             2237   7949260
# 10714        K               K           GB             2062   7949260
#
#        event_team_id home_visitor   fav_dog  proj_points  ownership  \
# 0           62097602         Home  Favorite         0.00       0.00
# 1           62097602         Home  Favorite        10.91      39.03
# 2           62097602         Home  Favorite         2.16       5.12
# 3           62097601      Visitor       Dog         0.00       0.00
# 4           62097601      Visitor       Dog         0.00       0.03
# ...              ...          ...       ...          ...        ...
# 10710       79433802         Home       Dog         0.00       0.00
# 10711       79492602         Home       Dog        29.73       0.00
# 10712       79492601      Visitor  Favorite         0.00       0.00
# 10713       79492602         Home       Dog         5.14       5.04
# 10714       79492601      Visitor  Favorite         8.45      26.12
#
#        actual_points                                   stat_details  made_cut
# 0                0.0                                                        0
# 1               20.8  1 RuTD, 1 RecTD, 21 RuYds, 47 RecYds, 2 Rec,          0
# 2                0.3                                      3 RuYds,          0
# 3                0.0                                                        0
# 4                0.0                                                        0
# ...              ...                                            ...       ...
# 10710            0.0                                                        0
# 10711           25.5                    1 RecTD, 40 RecYds, 7 Rec,          0
# 10712            0.0                                                        0
# 10713            1.0     1 SACK, 1 DFR, 1 BLK,  35+ Points Allowed          0
# 10714           12.0                                                        0
#
# [10715 rows x 19 columns]
